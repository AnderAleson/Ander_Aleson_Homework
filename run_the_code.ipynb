# %% [markdown]
# # Here you can run the code in the notebook format

# %% [markdown]
# First we import the created package

# %%
import ander_package
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# To call the modules of the packages is as easy as:

# %%
ander_package.Harmonic_fitter("H2_scan.log")

# %%
ander_package.Morse_fitter("H2_scan.log")

# %% [markdown]
# After runing the code and saw the plots, also two .png files were generated that store the plots
